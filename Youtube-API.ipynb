# %%
#working with APIs in python- for your data science project


import requests
import pandas as pd
import time

#keys

Api_key = "AIzaSyDsL8dTJSvQ3ZlnR_HAyrLpdGix7lIi09E"
channel_id ="UCW8Ews7tdKKkBT6GdtQaXvQ"

#make API call test. 

#response = requests.get("https://api.github.com").json()
#response

#API call
pageToken = " "

url = "https://www.googleapis.com/youtube/v3/search?key="+Api_key+"&channelid="+channel_id+"&part=snippet,id&order=date&maxResults=10000"
response = requests.get(url).json()

response["items"][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'oqhNcho0Ovxt9e_9UJub824f4Yk',
#  'id': {'kind': 'youtube#video', 'videoId': '0g4YEaelu00'},
#  'snippet': {'publishedAt': '2022-03-10T12:09:47Z',
#   'channelId': 'UCWlV3Lz_55UaX4JsMj-z__Q',
#   'title': '서울·1기 신도시 재건축 기대감↑…&#39;종부세 폐지&#39; &#39;임대차 3법 손질&#39;도 추진될 듯',
#   'description': '윤석열 후보, 당선으로 부동산 정책에도 변화가 예고됐습니다. 윤 당선인은 규제 완화와 주택 공급에 방점을 찍고 있는데요, 부동산 ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0g4YEaelu00/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/0g4YEaelu00/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/0g4YEaelu00/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': '뉴스TVCHOSUN',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2022-03-10T12:09:47Z'}}

# %%
#to have the program going through all the videos we have to build loop. 

for video in response["items"]:
    if video["id"]["kind"] == "youtube#video":
        video_Id =video["id"]["videoId"]
        video_title = video["snippet"]["title"]
        video_title = str(video_title).replace("&apm;", " ")
        upload_date = video["snippet"]["publishedAt"]
        upload_date = str(upload_date).split("T")[0]
        
        #collecting view, like, favour, comments counts. 
        url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_Id+"&part=statistics&key="+Api_key
        response_video_stats = requests.get(url_video_stats).json()

        view_count = response_video_stats["items"][0]["statistics"]["viewCount"]
        like_count = response_video_stats["items"][0]["statistics"]["likeCount"]
        favor_count = response_video_stats["items"][0]["statistics"]["favoriteCount"]
        

        print(video_Id)
        print(video_title)
        print(upload_date)
        print(view_count)
        print(like_count)
        print(favor_count)
# Out:
# q0Fr6IVo4pk
# Efforts Intensify To Help Civilians Escape Fighting In Ukraine
# 2022-03-08
# 656
# 20
# 0
# o0WAB1lOlJc
# 【プレミア公開】1.29名古屋 ワールド王座戦 朱里vsMIRAI/ゴッデス FWC vs 舞ひめ/SWA決定戦 白川未奈vsテクラ/『We are STARDOM!!』#114【STARDOM】
# 2022-03-08
# 4816
# 262
# 0
# f6BcY0DbOhA
# &quot;Наши дети умирают&quot;
# 2022-03-08
# 17595
# 1288
# 0
# uELb6abTPuA
# Akhilesh Yadav की प्रेस वार्ता  ||  Live |
# 2022-03-08
# 10810
# 4794
# 0
# f9cySrEiC6A
# 윤석열, 강남역서 마지막 지지 호소…2030 표심 집중공략 / 연합뉴스TV (YonhapnewsTV)
# 2022-03-08
# 24004
# 1193
# 0
# k5s_PcA0B-I
# Darcey Announces She Is No Longer Engaged to Georgi | Darcey &amp; Stacey
# 2022-03-08
# 7730
# 504
# 0
# I6RBnE5fzmo
# [SFM FNaF] Security Breach vs FNaF AR WITH Healthbars
# 2022-03-08
# 6127
# 245
# 0
# aFzDX73uUVU
# ⚡️Срочно | Спецоперация на Украине | Что происходит | Война с ФЕЙКАМИ
# 2022-03-08
# 5331
# 476
# 0
# H4uXo63nf7c
# Police launch crackdown on rogue boda boda operators in Nairobi
# 2022-03-08
# 5473
# 88
# 0
# gMF_gYyBObY
# ...

# %%
#build our data frame
df = pd.DataFrame(columns=["video_Id", "video_title", "upload_date", "view_count", "like_count", "favor_count"])
df
# Out:
# Empty DataFrame
# Columns: [video_Id, video_title, upload_date, view_count, like_count, favor_count]
# Index: []

# %%
for video in response["items"]:
    if video["id"]["kind"] == "youtube#video":
        video_Id =video["id"]["videoId"]
        video_title = video["snippet"]["title"]
        video_title = str(video_title).replace("&apm;", " ")
        upload_date = video["snippet"]["publishedAt"]
        upload_date = str(upload_date).split("T")[0]
        
        #collecting view, like, favour, comments counts. 
        url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_Id+"&part=statistics&key="+Api_key
        response_video_stats = requests.get(url_video_stats).json()

        view_count = response_video_stats["items"][0]["statistics"]["viewCount"]
        like_count = response_video_stats["items"][0]["statistics"]["likeCount"]
        favor_count = response_video_stats["items"][0]["statistics"]["favoriteCount"]
        
        #save the data in pandas df
        df = df.append({"video_Id": video_Id, "video_title": video_title, "upload_date": upload_date, 
                        "view_count": view_count , "like_count": like_count, "favor_count": favor_count}, ignore_index=True)

# %%
df.head()
# Out:
#       video_Id                                        video_title upload_date  \
# 0  q0Fr6IVo4pk  Efforts Intensify To Help Civilians Escape Fig...  2022-03-08
# 1  o0WAB1lOlJc  【プレミア公開】1.29名古屋 ワールド王座戦 朱里vsMIRAI/ゴッデス FWC vs ...  2022-03-08
# 2  f6BcY0DbOhA                      &quot;Наши дети умирают&quot;  2022-03-08
# 3  uELb6abTPuA         Akhilesh Yadav की प्रेस वार्ता  ||  Live |  2022-03-08
# 4  f9cySrEiC6A  윤석열, 강남역서 마지막 지지 호소…2030 표심 집중공략 / 연합뉴스TV (Yon...  2022-03-08
#
#   view_count like_count favor_count
# 0        721         23           0
# 1       4971        273           0
# 2      17921       1393           0
# 3      14939       4994           0
# 4      24700       1276           0
